# %% [markdown]
# <a href="https://colab.research.google.com/github/NextWaveGit/deeplearning/blob/master/ipaApp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ipa import Ipa

import time

drive = '/content/drive/My Drive/ml/ipa/data'

train_dir = drive+'/train'
test_dir = drive+'/test'
score_dir = drive+'/score'

ipa = Ipa()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir('drive/My Drive/ml/ipa')

# %%
# !python ipa.py --train
# Out:
# Using TensorFlow backend.
# Found 611 images belonging to 2 classes.
# 2019-01-04 02:30:19.282219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-01-04 02:30:19.282696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-01-04 02:30:19.282756: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2019-01-04 02:30:19.714254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-01-04 02:30:19.714310: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# ...

# %%
# !python ipa.py --test
# Out:
# Using TensorFlow backend.
# Found 21 images belonging to 2 classes.
# 2019-01-04 02:33:28.294210: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-01-04 02:33:28.294736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2019-01-04 02:33:28.294781: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2019-01-04 02:33:28.738072: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-01-04 02:33:28.738171: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2019-01-04 02:33:28.738217: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# ...

# %%
start_time = time.time()
ipa.train(train_dir)
print("--- train %s seconds ---" % (time.time() - start_time))
# Out:
# Found 611 images belonging to 2 classes.
# ...
# 58892288/58889256 [==============================] - 3s 0us/step
# Epoch 1/10
# 611/611 [==============================] - 1s 2ms/step - loss: 1.3011 - acc: 0.5352
# Epoch 2/10
# 611/611 [==============================] - 0s 96us/step - loss: 0.5220 - acc: 0.7250
# Epoch 3/10
# 611/611 [==============================] - 0s 90us/step - loss: 0.3899 - acc: 0.8249
# Epoch 4/10
# 611/611 [==============================] - 0s 87us/step - loss: 0.2883 - acc: 0.8936
# Epoch 5/10
# 611/611 [==============================] - 0s 86us/step - loss: 0.2678 - acc: 0.8887
# Epoch 6/10
# 611/611 [==============================] - 0s 88us/step - loss: 0.2225 - acc: 0.9067
# Epoch 7/10
# 611/611 [==============================] - 0s 88us/step - loss: 0.1951 - acc: 0.9247
# Epoch 8/10
# 611/611 [==============================] - 0s 112us/step - loss: 0.1601 - acc: 0.9378
# Epoch 9/10
# ...

# %%
start_time = time.time()
results = ipa.predict(test_dir)
results.to_csv('test_scores',index=False)
print("--- test %s seconds ---" % (time.time() - start_time))
# Out:
# Found 21 images belonging to 2 classes.
# --- test 9.214887142181396 seconds ---

# %%
results
# Out:
#                                              Filename  Labels     Score
# 0                                      negative/1.jpg       0  0.064758
# 1                                     negative/10.jpg       0  0.114857
# 2                                      negative/2.JPG       0  0.032143
# 3                                      negative/3.jpg       0  0.010204
# 4                                      negative/4.jpg       0  0.009110
# 5                                      negative/5.jpg       0  0.009358
# 6                                      negative/6.jpg       0  0.015672
# 7                                      negative/7.jpg       0  0.388859
# 8                                      negative/8.jpg       0  0.064758
# 9                                      negative/9.jpg       0  0.004362
# 10               positive/04trees-span-superJumbo.jpg       1  0.953688
# 11                                     positive/1.jpg       1  0.966318
# ...

# %%
start_time = time.time()
results = ipa.predict(score_dir)
results = results.drop(['Labels'], axis=1)
results.to_csv('scores',index=False)
print("--- predict %s seconds ---" % (time.time() - start_time))
# Out:
# Found 55 images belonging to 1 classes.
# --- predict 19.674078702926636 seconds ---

# %%
results
# Out:
#                                              Filename     Score
# 0                                nolabels/0220C64.jpg  0.005197
# 1                            nolabels/032C78dmgd3.jpg  0.999871
# 2                           nolabels/05E09Fdmgd17.jpg  0.999397
# 3                            nolabels/090471dmgd5.jpg  0.565802
# 4                           nolabels/143E87dmgd14.jpg  0.823515
# 5                                nolabels/1949504.jpg  0.005197
# 6                                nolabels/1B635E1.jpg  0.059105
# 7                           nolabels/21241Cdmgd15.jpg  0.994173
# 8   nolabels/24A5FAHome-repair-grants-hurricane-fl...  0.998917
# 9                           nolabels/26ADA2dmgd16.jpg  0.963738
# 10                           nolabels/276DD8dmgd3.jpg  0.999871
# 11      nolabels/2D922C11091947-dachstuhl-abreien.jpg  0.996844
# 12                           nolabels/35C47Edmgd8.jpg  0.247075
# 13                          nolabels/3D04C7dmgd12.jpg  0.999560
# ...
